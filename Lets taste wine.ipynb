# %%
import pandas as pd

# %%
df = pd.read_csv("wine.csv")
df.head()
# Out:
#    Unnamed: 0  volume  Alcohol  Malic acid   Ash  Alcalinity     Mg  \
# 0           0     1.0    13.20        1.78  2.14        11.2  100.0
# 1           1     1.0    13.16        2.36  2.67        18.6  101.0
# 2           2     1.0    14.37        1.95  2.50        16.8  113.0
# 3           3     1.0    13.24        2.59  2.87        21.0  118.0
# 4           4     1.0    14.20        1.76  2.45        15.2  112.0
#
#    Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0           2.65        2.76                  0.26             1.28
# 1           2.80        3.24                  0.30             2.81
# 2           3.85        3.49                  0.24             2.18
# 3           2.80        2.69                  0.39             1.82
# 4           3.27        3.39                  0.34             1.97
#
#    Color intensity   Hue    OD  Proline
# 0             4.38  1.05  3.40   1050.0
# 1             5.68  1.03  3.17   1185.0
# ...

# %%
df.set_index()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-a0581cb84c9b> in <module>()
# ----> 1 df.set_index()
#
# TypeError: set_index() missing 1 required positional argument: 'keys'
